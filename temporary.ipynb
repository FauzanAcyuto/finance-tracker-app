# %%
from modules import io_ops
import pandas as pd
from sqlalchemy import create_engine
from datetime import datetime

# %%
CONNSTR = f'mysql+pymysql://casaos:casaos@192.168.0.101:3306/casaos'

engine = create_engine(CONNSTR)

# %%
#with engine.connect() as conn:
    conn.execute("ALTER TABLE personal_finance_data ALTER COLUMN \"TIME\" TYPE DATE USING \"TIME\"::date")

# %%
data = pd.read_csv("export_24_08_23_959.csv",delimiter=",")
data
# Out:
#                      TIME         TYPE     AMOUNT            CATEGORY  \
# 0    Dec 21, 2022 1:49 PM   (+) Income  2581000.0        House Income
# 1    Dec 21, 2022 1:50 PM   (+) Income   500000.0                Gift
# 2    Dec 21, 2022 1:52 PM   (+) Income   264000.0      Reimbursements
# 3    Dec 21, 2022 1:55 PM  (-) Expense   824000.0         Electronics
# 4    Dec 21, 2022 1:56 PM  (-) Expense   700000.0             Savings
# ..                    ...          ...        ...                 ...
# 518  Aug 22, 2023 8:51 PM  (-) Expense   302500.0              Social
# 519  Aug 24, 2023 8:51 PM   (+) Income   400000.0                Gift
# 520  Aug 24, 2023 8:53 PM  (-) Expense   375000.0              Social
# 521  Aug 24, 2023 8:53 PM  (-) Expense    41000.0      Transportation
# 522  Aug 24, 2023 9:57 PM  (-) Expense  1580000.0  Trully unaccounted
#
#           ACCOUNT                                             NOTES
# ...

# %%
for i, row in data.iterrows():   
    data.loc[i,"TIME"] = data.loc[i,"TIME"].rsplit(" ",2)[0]
    data.loc[i,"TIME"] = datetime.strptime(data.loc[i,"TIME"],"%b %d, %Y")
    data.loc[i,"TIME"] = datetime.strftime(data.loc[i,"TIME"],"%Y-%m-%d")

# %%
data.columns = data.columns.str.strip()

# %%
data.to_sql("personal_finance_data",engine,if_exists='fail',index=False)
# Out:
# 523

# %%
new_record = ['2023-08-28', 'Expense', 'Food', '9999', 'test']

# %%
columns = ["TIME", "TYPE", "CATEGORY", "AMOUNT", "NOTES"]

# %%
df = io_ops.read_sql(columns)

# %%
df
# Out:
# [[datetime.date(2022, 12, 21),
#   '(+) Income',
#   'House Income',
#   2581000.0,
#   'gaji dari papah\n '],
#  [datetime.date(2022, 12, 21),
#   '(+) Income',
#   'Gift',
#   500000.0,
#   'uang beli pc dari papah '],
#  [datetime.date(2022, 12, 21),
#   '(+) Income',
#   'Reimbursements',
#   264000.0,
#   'tabungan jajan '],
#  [datetime.date(2022, 12, 21),
#   '(-) Expense',
#   'Electronics',
#   824000.0,
#   'minipc + ssd 120gb + mounting brackets and cables '],
#  [datetime.date(2022, 12, 21),
#   '(-) Expense',
#   'Savings',
#   700000.0,
#   'dana darurat '],
#  [datetime.date(2022, 12, 21), '(-) Expense', 'Admin fee', 4000.0, 'admin '],
#  [datetime.date(2022, 12, 21), '(-) Expense', 'Food', 50000.0, 'dana warkop '],
#  [datetime.date(2022, 12, 22), '(-) Expense', 'Gas', 25000.0, 'shell '],
#  [datetime.date(2022, 12, 22),
#   '(+) Income',
#   'Reimbursements',
#   259000.0,
#   'uang dari dana jajan sama sisa saldo pluang '],
#  [datetime.date(2022, 12, 22),
# ...

# %%
df = pd.DataFrame([new_record],columns=["TIME", "TYPE", "CATEGORY", "AMOUNT", "NOTES"])

# %%
df
# Out:
#          TIME     TYPE CATEGORY AMOUNT NOTES
# 0  2023-08-28  Expense     Food   9999  test
